# %%
# 1.1 Plot the bar graph of number of restaurants present in Delhi NCR vs Rest of India.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import Counter

start=pd.read_csv('zomato.csv',encoding='latin-1')
data=start.copy()
cities=[]

for i in data['City']:
    if (i=='New Delhi')|(i=='Ghaziabad')|(i=='Noida')|(i=='Gurgaon')|(i=='Faridabad'):
        data['City'].replace(i,"Delhi-NCR",inplace=True)
    else:
        data['City'].replace(i,"Rest of India",inplace=True)


for i,j in zip(data['Country Code'],data['City']):
    if i==1:
        cities.append(j)

citiesdict={}

for city in cities:
    if  city=='Delhi-NCR':
        if city in citiesdict:
            citiesdict[city]+=1
        else:
            citiesdict[city]=1
    else:
        city='Rest of India'
        if city in citiesdict:
            citiesdict[city]+=1
        else:
            citiesdict[city]=1

res_city=[]
res_no=[]
for key,value in citiesdict.items():
    res_city.append(key)
    res_no.append(value)
    print(key,value)
# Bar Graph code
plt.bar(res_city, res_no,color=('lightseagreen','mediumslateblue'))
plt.xlabel('City')
plt.ylabel('Number of Restaurants')
plt.xticks(label=res_city) 
plt.title('')
plt.show()
# Out:
# Rest of India 705
# Delhi-NCR 7947

# %%
#1.2 Find the cuisines which are not present in restaurant of Delhi NCR but present in rest of India.
#    Check using Zomato API whether this cuisines are actually not served in 

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import Counter

start=pd.read_csv('zomato.csv',encoding='latin-1')
data=start.copy()
data['Cuisines']=data['Cuisines'].fillna("")

for j,i in zip(data['Country Code'],data['City']):
        if j==1:
            if (i=='New Delhi')|(i=='Ghaziabad')|(i=='Noida')|(i=='Gurgaon')|(i=='Faridabad'):
                data['City'].replace(i,"Delhi-NCR",inplace=True)
            else:
                data['City'].replace(i,"Rest of India",inplace=True)

del_cu=[]
rest_cu=[]
for i,j in zip(data['City'],data['Cuisines']):
    if i=='Delhi-NCR':
        for z in j.split(','):
            del_cu.append(z.strip())
    elif i=='Rest of India':
        for k in j.split(','):
            rest_cu.append(k.strip())
def Diff(li1, li2): 
    return (list(set(li1) - set(li2))) 
del_cu=set(del_cu)

rest_cu=set(rest_cu)

not_ser=Diff(rest_cu,del_cu)
for i in not_ser:
    print(i)
# Out:
# German
# Malwani
# BBQ
# Cajun

# %%
#1.3 Find the top 10 cuisines served by maximum number of restaurants in Delhi NCR and rest of India.

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import Counter

start=pd.read_csv('zomato.csv',encoding='latin-1')
data=start.copy()
data['Cuisines']=data['Cuisines'].fillna("")

cities=[]

for j,i in zip(data['Country Code'],data['City']):
        if j==1:
            if (i=='New Delhi')|(i=='Ghaziabad')|(i=='Noida')|(i=='Gurgaon')|(i=='Faridabad'):
                data['City'].replace(i,"Delhi-NCR",inplace=True)
            else:
                data['City'].replace(i,"Rest of India",inplace=True)
del_cu=[]
rest_cu=[]
cusines=[]
cusines
for i,j in zip(data['City'],data['Cuisines']):
    if (i=='Delhi-NCR')|(i=='Rest of India'):    
        for z in j.split(','):
            cusines.append(z.strip())
            
cusines_max={}

for i in cusines:
    if i in cusines_max:
        cusines_max[i]+=1
    else:
        cusines_max[i]=1

d=Counter(cusines_max).most_common(10)
cus_name=[]
cus_no=[]
for i in d:
    cus_name.append(i[0])
    cus_no.append(i[1])
    print(i[0],i[1])
# Bar Graph code
plt.bar(cus_name, cus_no,color='lightgreen',edgecolor='black')
plt.xlabel('CUSINE NAME')
plt.ylabel('Maximum Served')
plt.xticks(label=cus_name, rotation=45) 
plt.title('Top 10 cuisines served by maximum number of restaurants in Delhi NCR and rest of India')
plt.show()
# Out:
# North Indian 3946
# Chinese 2690
# Fast Food 1963
# Mughlai 992
# Bakery 726
# Continental 724
# Italian 682
# South Indian 631
# Cafe 627
# Desserts 597

# %%
#1.4 Write a short detailed analysis of how cuisine served is different from Delhi NCR to Rest of India. 
# Plot the suitable graph to explain your inference.


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import Counter

start=pd.read_csv('zomato.csv',encoding='latin-1')
data=start.copy()
data['Cuisines']=data['Cuisines'].fillna("")

for j,i in zip(data['Country Code'],data['City']):
        if j==1:
            if (i=='New Delhi')|(i=='Ghaziabad')|(i=='Noida')|(i=='Gurgaon')|(i=='Faridabad'):
                data['City'].replace(i,"Delhi-NCR",inplace=True)
            else:
                data['City'].replace(i,"Rest of India",inplace=True)

del_cu=[]
rest_cu=[]
for i,j in zip(data['City'],data['Cuisines']):
    if i=='Delhi-NCR':
        for z in j.split(','):
            del_cu.append(z.strip())
    elif i=='Rest of India':
        for k in j.split(','):
            rest_cu.append(k.strip())

del_cu=set(del_cu)
rest_cu=set(rest_cu)
cuisines=[len(del_cu),len(rest_cu)]
cities=['Delhi-NCR','Rest of India']
for i,j in zip(cities,cuisines):
    print(i,j)
# Bar Graph code
plt.bar(cities,cuisines,color=('tomato','mediumslateblue'))
plt.xlabel('City')
plt.ylabel('Number of Cuisines')
plt.xticks(label=res_city) 
plt.title('')
plt.show()
# Out:
# Delhi-NCR 86
# Rest of India 70

# %%
# User Rating of a restaurant plays a crucial role in selecting a restaurant or ordering the food from the restaurant.
#Write a short detail analysis of how the rating is affected by restaurant due following features: Plot a suitable graph to explain your inference.
# 2.1.1  Number of Votes given Restaurant

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from statistics import mean
from collections import Counter

start=pd.read_csv('zomato.csv',encoding='latin-1')
data=start.copy()



g1=[]
g2=[]
g3=[]
g4=[]
for i,j,k in zip(data['Votes'],data['Aggregate rating'],data['Country Code']):
    if k==1:
        if 0>=i & i<2500:
            g1.append(j)
        elif i==2500 & i<5000:
            g2.append(j)
        elif i==5000 & i<7500:
            g3.append(j)
        else:
            g4.append(j)

avg1=mean(g1)
avg2=mean(g2)
avg3=mean(g3)
avg4=mean(g4)

avg=[avg1,avg2,avg3,avg4]
grp=['0-2500','2500-5000','5000-7500','7500-11000']

plt.plot(grp,avg,'-s',linewidth=2, markersize=12,color='mediumorchid')
plt.ylabel('Average Ratings')
plt.xlabel('Number of Votes')
plt.grid()
plt.show()

# %%
# User Rating of a restaurant plays a crucial role in selecting a restaurant or ordering the food from the restaurant.
#Write a short detail analysis of how the rating is affected by restaurant due following features: Plot a suitable graph to explain your inference.
# 2.1.2  Restaurant serving more number of cuisines.

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from statistics import mean

from collections import Counter

start=pd.read_csv('zomato.csv',encoding='latin-1')
data=start.copy()
data['Cuisines']=data['Cuisines'].fillna("")

cities=[]

g1=[]
g2=[]
g3=[]
g4=[]
g5=[]

for i,j,z in zip(data['Aggregate rating'],data['Cuisines'],data['Country Code']):  
      if z==1:      
            k=len(j.split(','))
            if 1>=k & k<3:
                g1.append(i)
            elif k==3 & k<5:
                g2.append(i)
            elif k==5 & k<7:
                g3.append(i)
            elif k==7 & k<9:
                g4.append(i)
            else:
                g5.append(i)

avg1=round(mean(g1),2)
avg2=round(mean(g2),2)
avg3=round(mean(g3),2)
avg4=round(mean(g4),2)
avg5=round(mean(g5),2)

cuisines=['0-2','2-4','4-6','6-8','8-10']
avg=[avg1,avg2,avg3,avg4,avg5]


plt.plot(cuisines,avg,'-*',linewidth=2, markersize=14,color='darkturquoise')
plt.ylabel('Average Ratings')
plt.xlabel('Number of Cusines in Restaurants')
plt.grid()
plt.show()

# %%
#2.1.3 Average Cost of Restaurant

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from statistics import mean

from collections import Counter

start=pd.read_csv('zomato.csv',encoding='latin-1')
data=start.copy()
data['Cuisines']=data['Cuisines'].fillna("")

cities=[]

g1=[]
g2=[]
g3=[]
g4=[]
g5=[]

for i,j,k in zip(data['Aggregate rating'],data['Average Cost for two'],data['Country Code']):  
         if k==1:   
            if 0>=j & j<1600:
                g1.append(i)
            elif j==1600 & j<3200:
                g2.append(i)
            elif j==3200 & j<4800:
                g3.append(i)
            elif j==4800 & j<6400:
                g4.append(i)
            else:
                g5.append(i)

avg1=round(mean(g1),2)
avg2=round(mean(g2),2)
avg3=round(mean(g3),2)
avg4=round(mean(g4),2)
avg5=round(mean(g5),2)


avgc=['0-1600','1600-3200','3200-4800','4800-6400','6400-8000']
avg=[avg1,avg2,avg3,avg4,avg5]


plt.plot(avgc,avg,'-X',linewidth=2, markersize=10,color='darkGREY')
plt.ylabel('Average Ratings')
plt.xlabel('Average Cost For Two')
plt.grid()
plt.show()

# %%
# 2.1.4 Restaurant serving some specific cuisines

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import Counter

start=pd.read_csv('zomato.csv',encoding='latin-1')
data=start.copy()
data['Cuisines']=data['Cuisines'].fillna("")

cu=[]
cusines=[]
for i,j,k in zip(data['Country Code'],data['Cuisines'],data['Aggregate rating']):
    if i==1:
        for z in j.split(','):
            cu.append([z.strip(),k])
            cusines.append(z.strip())
cus={}
cusc={}
cusr={}
cusines=set(cusines)
for j in cu:
    a=j[0]
    b=j[1]
    for i in cusines:
        if i==a:
                if a in cus:
                    cus[a]+=b
                    cusc[a]+=1
                else:
                    cus[a]=b
                    cusc[a]=1

for i,j,k in zip(cus,cus.values(),cusc.values()):
    cusr[i]=round(j/k,2)

    
import operator
cusi=[]
avg=[]

d = dict( sorted(cusr.items(), key=operator.itemgetter(1)))
for i,j in d.items():
    cusi.append(i)
    avg.append(j)

plt.plot(avg[1:],cusi[1:],'-X',linewidth=2, markersize=1,color='darkGREY')
plt.xlabel('Average Ratings')
plt.ylabel('Cuisines')
plt.grid()
plt.show()

cusisample=[]
avgsample=[]
count=0
for i,j in d.items():
    if count<11:
        cusisample.append(i)
        avgsample.append(j)
        count=count+1
plt.plot(avgsample[1:],cusisample[1:],'-X',linewidth=2, markersize=1,color='darkGREY')
plt.xlabel('Average Ratings')
plt.ylabel('Cuisines')
plt.grid()
plt.show()

# %%
#2.2 Find the weighted restaurant rating of each locality and find out the top 10 localities with more weighted restaurant rating?
#    Weighted Restaurant Rating=Σ (number of votes * rating) / Σ (number of votes)


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import Counter

start=pd.read_csv('zomato.csv',encoding='latin-1')
data=start.copy()
data['Cuisines']=data['Cuisines'].fillna("")

votes=[]
rating=[]
locality=[]

loc_data=[]
for i,j in zip(data['Locality Verbose'],data['Country Code']):
    if j==1:
        locality.append(i)
locality=set(locality)

locality_name=[]
locality_weight=[]

# calculating weights
for i in locality:
    vote=0
    vote_rating=0
    vote_sum=0
    vote_rating_sum=0
    for j,k,l in zip(data['Locality Verbose'],data['Votes'],data['Aggregate rating']):
        if (i==j):
            vote=k
            vote_rating=k*l
            vote_sum=vote_sum+vote
            vote_rating_sum=vote_rating_sum+vote_rating
            
    if vote_sum==0:
        weight=0
    else:
        weight=(vote_rating_sum/vote_sum)
        weight=round(weight,2)
    loc_data.extend((i,weight))
    locality_name.append(i)
    locality_weight.append(weight)

# creating dict of localities
loc_dic={}
for i,j in zip(locality_name,locality_weight):
    loc_dic[i]=j
# finding top 10 localities 
d=Counter(loc_dic).most_common(10)
loc_name=[]
loc_wei=[]
for i in d:
    loc_name.append(i[0])
    loc_wei.append(i[1])
    print(i[0],i[1])
# Out:
# Aminabad, Lucknow 4.9
# Hotel Clarks Amer, Malviya Nagar, Jaipur 4.9
# Friends Colony, New Delhi 4.89
# Powai, Mumbai 4.84
# Kirlampudi Layout, Vizag 4.82
# Deccan Gymkhana, Pune 4.8
# Express Avenue Mall,  Royapettah, Chennai 4.8
# Banjara Hills, Hyderabad 4.72
# Sector 5, Salt Lake, Kolkata 4.71
# Riverside Mall, Gomti Nagar, Lucknow 4.7

# %%
# 3.1 Plot the bar graph top 15 restaurants have a maximum number of outlets.

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import Counter

start=pd.read_csv('zomato.csv',encoding='latin-1')
data=start.copy()

rest=[]
rest_data=[]
for i,j in zip(data['Restaurant Name'],data['Country Code']):
    if j==1:
        rest.append(i)

rest_dic={}

for i in rest:
    if i in rest_dic:
        rest_dic[i]=rest_dic[i]+1
    else:
        rest_dic[i]=1
# creating dict of localities
d=Counter(rest_dic).most_common(15)


# finding top 15 restaurant with max no of outlets 
res_name=[]
res_no=[]
for i in d:
    res_name.append(i[0])
    res_no.append(i[1])
    print(i[0],i[1])
            
# Bar Graph code

plt.bar(res_name, res_no,color=('g'),edgecolor='black')
plt.xlabel('Name of Restaurant')
plt.ylabel('Number of Outlets')
plt.xticks(label=res_name,rotation=50) 
plt.title('')
plt.show()
# Out:
# Cafe Coffee Day 83
# Domino's Pizza 79
# Subway 63
# Green Chick Chop 51
# McDonald's 48
# Keventers 34
# Pizza Hut 29
# Giani 29
# Baskin Robbins 28
# Barbeque Nation 25
# Dunkin' Donuts 22
# Giani's 22
# Barista 22
# Pind Balluchi 20
# Costa Coffee 20

# %%
# 3.2 Plot the histogram of aggregate rating of restaurant( drop the unrated restaurant)

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

start=pd.read_csv('zomato.csv',encoding='latin-1')
df=start.copy()



rest=[]
rest_data=[]
for i,j in zip(df['Aggregate rating'],df['Country Code']):
     if j==1 and i>0:   
        rest.append(i)
plt.hist(rest,bins=10,edgecolor='black',
              linewidth=1,color = "skyblue")
plt.ylabel('No of Ratings')
plt.xlabel('Ratings')
plt.show()

# %%
#3.3 Plot the bar graph top 10 restaurants in the data with the highest number of votes.


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import Counter

start=pd.read_csv('zomato.csv',encoding='latin-1')
data=start.copy()

rest=[]
rest_data=[]
for i in data['Restaurant Name']:
    rest.append(i)

# calculating weights
rest_name=[]
rest_votes=[]
for i,j,k in zip(data['Restaurant Name'],data['Votes'],data['Country Code']):
        if k==1:
            rest_data.extend((i,count))
            rest_name.append(i)
            rest_votes.append(j)

# creating dict of localities
rest_dic={}
for i,j in zip(rest_name,rest_votes):
    if i in rest_dic:
        if j>rest_dic[i]:
            rest_dic[i]=j
    if i not in rest_dic:
            rest_dic[i]=j
# finding top 10 restaurant with max votes 
d=Counter(rest_dic).most_common(10)
res_name=[]
res_votes=[]

for i in d:
    res_name.append(i[0])
    res_votes.append(i[1])
    print(i[0],i[1])
            
# Bar Graph code

plt.bar(res_name, res_votes,color=('orange'),edgecolor='black')
plt.xlabel('Name of Restaurant')
plt.ylabel('Number of Votes')
plt.xticks(label=res_name,rotation=50) 
plt.title('')
plt.show()
# Out:
# Toit 10934
# Truffles 9667
# Hauz Khas Social 7931
# Peter Cat 7574
# AB's - Absolute Barbecues 6907
# Barbeque Nation 5966
# Big Brewsky 5705
# The Black Pearl 5385
# BarBQ 5288
# Saravana Bhavan 5172

# %%
# 3.4 Plot the pie graph of top 10 cuisines present in restaurants in the USA


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import Counter

start=pd.read_csv('zomato.csv',encoding='latin-1')
data=start.copy()
data['Cuisines']=data['Cuisines'].fillna("")

cities=[]
del_cu=[]
rest_cu=[]
cusines=[]
cusines
for i,j in zip(data['Country Code'],data['Cuisines']):
    if (i==216):    
        for z in j.split(','):
            cusines.append(z.strip())
            
cusines_max={}

for i in cusines:
    if i in cusines_max:
        cusines_max[i]+=1
    else:
        cusines_max[i]=1

d=Counter(cusines_max).most_common(10)
cus_name=[]
cus_no=[]
for i in d:
    cus_name.append(i[0])
    cus_no.append(i[1])
    print(i[0],i[1])
# Bar Graph code
plt.bar(cus_name, cus_no,color='darkcyan',edgecolor='black')
plt.xlabel('CUSINE NAME')
plt.ylabel('Maximum Served')
plt.xticks(label=cus_name, rotation=45) 
plt.title('Top 10 cuisines present in restaurants in the USA')
plt.show()


plt.pie(cus_no,labels=cus_name,autopct='%.2f')
plt.title('Top 10 cuisines present in restaurants in the USA')
plt.axis('equal')   
plt.show()
# Out:
# American 112
# Seafood 59
# Burger 49
# Sandwich 49
# Pizza 49
# Steak 42
# Italian 38
# Breakfast 37
# Mexican 36
# Sushi 34

# %%
# 3.5 Plot the bubble graph of a number of Restaurants present in the city of India 
# and keeping the weighted restaurant rating of the city in a bubble.

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from collections import Counter

start=pd.read_csv('zomato.csv',encoding='latin-1')
data=start.copy()
data['Cuisines']=data['Cuisines'].fillna("")

for j,i in zip(data['Country Code'],data['City']):
    if j==1:
        if (i=='New Delhi')|(i=='Ghaziabad')|(i=='Noida')|(i=='Gurgaon')|(i=='Faridabad'):
            continue
        else:
            data['City'].replace(i,"Rest of India",inplace=True)

votes=[]
rating=[]
city=[]

_data=[]
for i,j in zip(data['City'],data['Country Code']):
        if j==1:
            city.append(i)
city=set(city)


city_name=[]
city_weight=[]
res_co=[]
# calculating weights
for i in city:
    vote=0
    vote_rating=0
    vote_sum=0
    vote_rating_sum=0
    res_count=0
    for j,k,l in zip(data['City'],data['Votes'],data['Aggregate rating']):
        
        if (i==j):
            vote=k
            vote_rating=k*l
            vote_sum=vote_sum+vote
            vote_rating_sum=vote_rating_sum+vote_rating
            res_count=res_count+1
            
    if vote_sum==0:
        weight=0
    else:
        weight=(vote_rating_sum/vote_sum)
        weight=round(weight,2)
    _data.extend((i,weight))
    city_name.append(i)
    city_weight.append(weight)
    res_co.append(res_count)

# creating dict of alities

for i,j,k in zip(city_name,city_weight,res_co):
    print(i,j,k)
            
# bubble chart
import numpy as np
c=np.arange(len(city_name))
plt.scatter(city_name,res_co,c=c,s=city_weight,edgecolor='b')
plt.axis([-.5,5.5,-20,6000])
plt.grid()
for i in range(0,6):
    r=str(city_weight[i])
    plt.text(city_name[i],res_co[i]+100,r)
plt.xlabel('City Name')
plt.ylabel('Restaurant Count')
plt.title('A Number of Restaurants present in the city of India and keeping the weighted restaurant rating of the city in a bubble')
plt.show()
# Out:
# New Delhi 3.77 5473
# Noida 3.47 1080
# Rest of India 4.24 705
# Gurgaon 3.74 1118
# Ghaziabad 3.04 25
# Faridabad 3.48 251
